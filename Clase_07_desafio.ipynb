# %% [markdown]
# <a href="https://colab.research.google.com/github/Lihuel/data-science/blob/main/Clase_07_desafio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manipulación de DataFrame con Pandas
# ![image.png](data:image/png;base64,...)

# %%
# @title Versión de Python
# !python --version
# Out:
# Python 3.10.12

# %%
# @title Importamos PANDAS

import pandas as pd

# %%
# @title Importar desde Drive

# Importar Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Ruta al archivo CSV en Google Drive
file_path = '/content/drive/My Drive/BD-BTC/BTCUSD_1hr.csv'

# Leer el archivo CSV
df = pd.read_csv(file_path)

# Mostrar las primeras filas
df.head()
#
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unix Timestamp                 Date  Symbol     Open     High      Low  \
# 0   1586390400000  2020-04-09 00:00:00  BTCUSD  7369.60  7369.60  7338.23
# 1   1586386800000  2020-04-08 23:00:00  BTCUSD  7367.28  7398.92  7348.47
# 2   1586383200000  2020-04-08 22:00:00  BTCUSD  7337.19  7390.25  7322.87
# 3   1586379600000  2020-04-08 21:00:00  BTCUSD  7327.70  7370.00  7311.33
# 4   1586376000000  2020-04-08 20:00:00  BTCUSD  7320.11  7375.72  7313.66
#
#      Close      Volume
# 0  7338.23    7.788915
# 1  7369.60   66.558293
# 2  7367.28   88.486108
# 3  7337.19   35.551553
# 4  7327.70  153.655811

# %% [markdown]
# #**df.describe()**
# `df.describe()` es un método de Pandas que genera estadísticas descriptivas para un DataFrame. Estas estadísticas incluyen recuento, media, desviación estándar, mínimo, percentiles y máximo para cada columna numérica del DataFrame.
#
# Al llamar `.round(1)` después de `df.describe()`, estás redondeando todos los valores de las estadísticas descriptivas a un decimal. Esto es útil para limitar la cantidad de decimales mostrados en el resultado.
#
# Por ejemplo, si tienes un DataFrame llamado df y quieres ver las estadísticas descriptivas redondeadas a un decimal, puedes hacer:
#
#
# ```
# df.describe().round(1)
# ```
#
# Esto te dará las estadísticas descriptivas para todas las columnas numéricas del DataFrame df con todos los valores redondeados a un decimal.

# %%
df.describe().round(1)
# Out:
#        Unix Timestamp                           Date     Open     High  \
# count    3.946500e+04                          39465  39465.0  39465.0
# mean     6.182322e+11  2018-01-07 17:14:41.733181440   4817.7   4844.9
# min      1.444309e+09            2015-10-08 13:00:00      0.0    243.6
# 25%      1.479827e+09            2016-11-22 15:00:00    741.7    743.0
# 50%      1.515344e+09            2018-01-07 17:00:00   4142.1   4165.4
# 75%      1.550862e+12            2019-02-22 19:00:00   7908.5   7950.0
# max      1.586390e+12            2020-04-09 00:00:00  19869.9  19999.0
# std      7.614885e+11                            NaN   3925.2   3954.1
#
#            Low    Close   Volume      mes      año
# count  39465.0  39465.0  39465.0  39465.0  39465.0
# mean    4788.7   4818.0    158.4      6.5   2017.5
# min        0.0    243.6      0.0      1.0   2015.0
# 25%      740.0    741.8     18.2      3.0   2016.0
# 50%     4118.4   4142.6     62.8      6.0   2018.0
# ...

# %% [markdown]
# #**df.info()**
#
# `df.info()` es un método de Pandas que se utiliza para imprimir un resumen conciso de un DataFrame, incluyendo información sobre el índice, el tipo de datos de cada columna y la cantidad de valores no nulos.
#
# Cuando llamas a `df.info()`, obtienes una salida que incluye:
#
# - La cantidad total de filas en el DataFrame.
# - El índice del DataFrame, incluyendo el rango de valores del índice y el tipo de datos del índice.
# - Información sobre cada columna, incluyendo el nombre de la columna, la cantidad de valores no nulos en esa columna y el tipo de datos de la columna.
#
# Este método es útil para obtener un resumen rápido de la estructura y el contenido de un DataFrame, especialmente cuando trabajas con conjuntos de datos grandes o desconocidos. Te permite verificar rápidamente el tamaño del DataFrame, los tipos de datos de las columnas y si hay valores faltantes en el conjunto de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39465 entries, 0 to 39464
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unix Timestamp  39465 non-null  int64
#  1   Date            39465 non-null  object
#  2   Symbol          39464 non-null  object
#  3   Open            39464 non-null  float64
#  4   High            39465 non-null  float64
#  5   Low             39465 non-null  float64
#  6   Close           39465 non-null  float64
#  7   Volume          39465 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 2.4+ MB

# %% [markdown]
# #**print(df.isna().sum())**
# `print(df.isna().sum())` es una expresión en Python que se utiliza para imprimir la cantidad de valores faltantes en cada columna de un DataFrame `df`.
#
# Aquí hay una explicación detallada de lo que hace esta expresión:
#
# - `df.isna()` es un método de Pandas que devuelve un DataFrame booleano con el mismo tamaño que el DataFrame original `df`, donde cada celda es `True` si el valor correspondiente en `df` es NaN (Not a Number), y `False` en caso contrario.
#
# - `.sum()` es un método que se aplica al DataFrame booleano devuelto por `df.isna()`. Cuando se aplica `.sum()` a un DataFrame booleano, suma los valores a lo largo de las columnas (axis=0 por defecto), devolviendo un Series que contiene la cantidad de valores `True` (es decir, los valores faltantes) en cada columna.
#
# - `print()` se utiliza para imprimir el resultado de `df.isna().sum()` en la consola.
#
# Entonces, `print(df.isna().sum())` imprime la cantidad de valores faltantes en cada columna del DataFrame `df`. Es una forma rápida de visualizar la cantidad de datos faltantes en tu conjunto de datos y entender dónde se encuentran.

# %%
print(df.isna().sum())
# Out:
# Unix Timestamp    0
# Date              0
# Symbol            0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# mes               0
# año               0
# dtype: int64

# %%
df.isna().sum()
# si todo estuvo ok debemos ver 0 como valores faltantes
# Out:
# Unix Timestamp    0
# Date              0
# Symbol            0
# Open              0
# High              0
# Low               0
# Close             0
# Volume            0
# dtype: int64

# %% [markdown]
# #**df.Symbol.unique()**
# `df.Symbol.unique()` es una expresión en Python que se utiliza para obtener los valores únicos de la columna "Symbol" de un DataFrame `df`.
#
# Aquí hay una explicación de lo que hace esta expresión:
#
# - `df.Symbol`: Accede a la columna "Symbol" del DataFrame `df`.
#
# - `.unique()`: Es un método de Pandas que se aplica a una Serie (una columna en este caso) y devuelve un array con los valores únicos de esa Serie, en el orden en que aparecen en los datos originales.
#
# Entonces, `df.Symbol.unique()` devuelve un array que contiene todos los valores únicos que aparecen en la columna "Symbol" del DataFrame `df`. Esto es útil para comprender qué tipos de valores o categorías existen en esa columna y para realizar análisis exploratorios sobre los datos.

# %%
# Symbol es una variable categórica, solo tenemos presente 'BTCUSD' por lo que podemos reemplazar por ese valor
df.Symbol.unique()
# Out:
# array(['BTCUSD'], dtype=object)

# %% [markdown]
# #**df["Date"]**
#
# `df["Date"]` en Python se refiere a la columna llamada "Date" en un DataFrame `df`. Esto se llama indexación de columna en Pandas.
#
# Cuando accedes a `df["Date"]`, estás obteniendo la Serie que representa la columna "Date" del DataFrame `df`. Puedes realizar varias operaciones y métodos de Pandas en esta Serie, como filtrar, realizar cálculos, aplicar funciones y más.
#
# Por ejemplo, puedes hacer lo siguiente:
#
# ```python
# # Obtener la Serie que representa la columna "Date"
# date_column = df["Date"]
#
# # Imprimir los primeros 5 elementos de la columna "Date"
# print(date_column.head())
#
# # Calcular la longitud de la columna "Date"
# print(len(date_column))
#
# # Filtrar el DataFrame basado en la columna "Date"
# filtered_df = df[df["Date"] > "2023-01-01"]
# ```
#
# Estos son solo algunos ejemplos de lo que puedes hacer con la columna "Date" del DataFrame `df`. Puedes manipular y analizar los datos de la fecha de varias maneras utilizando Pandas.

# %%
# Date esta como object vamos a pasarlo como objeto de tiempo

df["Date"]
# Out:
# 0       2020-04-09 00:00:00
# 1       2020-04-08 23:00:00
# 2       2020-04-08 22:00:00
# 3       2020-04-08 21:00:00
# 4       2020-04-08 20:00:00
#                 ...
# 39460   2015-10-08 17:00:00
# 39461   2015-10-08 16:00:00
# 39462   2015-10-08 15:00:00
# 39463   2015-10-08 14:00:00
# 39464   2015-10-08 13:00:00
# Name: Date, Length: 39465, dtype: datetime64[ns]

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%Y-%m-%d %H:%M:%S")
df["Date"]
# Out:
# 0       2020-04-09 00:00:00
# 1       2020-04-08 23:00:00
# 2       2020-04-08 22:00:00
# 3       2020-04-08 21:00:00
# 4       2020-04-08 20:00:00
#                 ...
# 39460   2015-10-08 17:00:00
# 39461   2015-10-08 16:00:00
# 39462   2015-10-08 15:00:00
# 39463   2015-10-08 14:00:00
# 39464   2015-10-08 13:00:00
# Name: Date, Length: 39465, dtype: datetime64[ns]

# %%
#extraemos el mes y año
df["mes"] = df["Date"].dt.month
df["año"] = df["Date"].dt.year
df
# Out:
#        Unix Timestamp                Date  Symbol     Open     High      Low  \
# 0       1586390400000 2020-04-09 00:00:00  BTCUSD  7369.60  7369.60  7338.23
# 1       1586386800000 2020-04-08 23:00:00  BTCUSD  7367.28  7398.92  7348.47
# 2       1586383200000 2020-04-08 22:00:00  BTCUSD  7337.19  7390.25  7322.87
# 3       1586379600000 2020-04-08 21:00:00  BTCUSD  7327.70  7370.00  7311.33
# 4       1586376000000 2020-04-08 20:00:00  BTCUSD  7320.11  7375.72  7313.66
# ...               ...                 ...     ...      ...      ...      ...
# 39460      1444323600 2015-10-08 17:00:00  BTCUSD   244.25   244.99   244.02
# 39461      1444320000 2015-10-08 16:00:00  BTCUSD   244.92   244.92   244.25
# 39462      1444316400 2015-10-08 15:00:00  BTCUSD   245.00   245.00   244.92
# 39463      1444312800 2015-10-08 14:00:00  BTCUSD   245.00   245.00   244.50
# 39464      1444309200 2015-10-08 13:00:00  BTCUSD     0.00   245.00     0.00
#
#          Close      Volume  mes   año
# ...

# %% [markdown]
# #**Group By**
# Aquí estamos realizando las siguientes operaciones en un DataFrame `df`:
#
# 1. `groupby(["año",'mes'])`: Agrupa el DataFrame por las columnas "año" y "mes". Esto significa que los datos se agruparán según los valores únicos de estas dos columnas.
#
# 2. `[['Open','High','Low','Close','Volume']]`: Selecciona las columnas "Open", "High", "Low", "Close" y "Volume" del DataFrame. Esto se hace para aplicar operaciones de agregación (como la media) a estas columnas después de agrupar los datos.
#
# 3. `.mean()`: Calcula la media de las columnas seleccionadas ("Open", "High", "Low", "Close", "Volume") para cada grupo creado por `groupby`. Esto significa que para cada combinación única de año y mes, se calcula la media de los valores en las columnas seleccionadas.
#
# 4. `.round(1)`: Redondea los valores en el DataFrame resultante a un decimal.
#
# Este código calcula la media de las columnas "Open", "High", "Low", "Close" y "Volume" para cada combinación única de año y mes en el DataFrame `df`, y redondea los valores resultantes a un decimal. Esto puede ser útil para obtener resúmenes estadísticos de los datos en función de la fecha.

# %%
df.groupby(["año",'mes'])[['Open','High','Low','Close','Volume']].mean().round(1)
# Out:
#              Open     High      Low    Close  Volume
# año  mes
# 2015 10     274.2    275.6    273.5    274.8    18.5
#      11     349.6    354.7    347.0    349.7    40.4
#      12     423.1    424.6    421.5    423.1    20.0
# 2016 1      411.5    412.7    410.2    411.4    39.8
#      2      401.8    402.5    401.2    401.9    41.6
#      3      414.4    414.7    413.9    414.3    55.3
#      4      433.7    434.0    433.4    433.7    52.0
#      5      461.0    461.7    460.5    461.1    43.7
#      6      640.5    643.3    637.6    640.7    83.4
#      7      661.8    662.8    660.5    661.7    41.0
#      8      580.9    581.9    579.9    580.9    47.8
#      9      604.2    604.6    603.7    604.3    69.0
#      10     640.4    641.0    639.9    640.5    96.9
#      11     724.4    725.5    723.3    724.5    88.5
#      12     821.4    823.0    820.2    821.7    86.1
# 2017 1      912.2    916.0    907.8    912.2   108.9
# ...

# %% [markdown]
# ## **Enlaces de interés**
#
#
#
#
# [Documentación Google Colab](https://colab.research.google.com/?hl=es)
#
# [Introducción Simple a Google Colab](https://www.youtube.com/watch?v=8VFYs3Ot_aA)
#
# [Documentación de Pandas Py](https://pandas.pydata.org/docs/)
